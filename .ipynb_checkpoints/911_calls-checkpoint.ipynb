# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 10
fig_size[1] = 5
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv('911 calls- Mongomery county/911.csv')
df = df[df['zip'] > 10000]

# %%
# lat: Latitude
# lng: Longitude
# desc: Description of Emergency
# zip: ZIP Code
# title: Title of Emergency
# time: StampDate and time of the call
# twp: Town
# addr: Address

# %%
print (df.head())
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 5  40.253473 -75.283245  CANNON AVE & W 9TH ST;  LANSDALE; Station 345;...
#
#        zip                    title            timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY  2015-12-10 17:10:52        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY  2015-12-10 17:29:21  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK  2015-12-10 14:39:21         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY  2015-12-10 16:47:36         NORRISTOWN
# 5  19446.0         EMS: HEAD INJURY  2015-12-10 15:39:04           LANSDALE
#
#                          addr  e
# 0      REINDEER CT & DEAD END  1
# 1  BRIAR PATH & WHITEMARSH LN  1
# 2                    HAWS AVE  1
# 3          AIRY ST & SWEDE ST  1
# 5       CANNON AVE & W 9TH ST  1

# %% [markdown]
# # Aspects to explore
# 1. How are emergencies ranked by frequency?<br>
#     1.1. What are the top few most frequent emergencies in each type? <br>
#     1.2. Subcategories by count.
#
# 2. Location based exploration <br>
#     2.1. Do specific emergencies happen at specific places more than the others?
#         - a. Plot emergency categories by 1. town,
#                                           2. zip,
#                                           3. Latitude, longitude
#         - b. Under categories, plot each sub category by 1. town,
#                                                          2. zip,
#                                                          3. Latitude, longitude.
#
# 3. Time based exploration<br>
#     3.1. Is there a specific time window when an emergency occurs?
#         - a. By time of day
#             - Plot emergency categories
#                 - Plot emergency subcategories
#         - b. By month
#             - Plot emergency categories
#                 - Plot emergency subcategories
#
# 4. Geo-temporal exploration<br>
#     4.1. Do emergencies show any pattern?
#         - a. At a given time, which place needs most attention? What type of attention is it?

# %%
df.columns = ['latitude','longitude','description','zip','type','time','town','address','if_emergency']

# %%
df.dtypes
# Out:
# latitude        float64
# longitude       float64
# description      object
# zip             float64
# type             object
# time             object
# town             object
# address          object
# if_emergency      int64
# dtype: object

# %%
df['time'] = pd.to_datetime(df['time'])
print (df['time'].max())
print (df['time'].min())
print (df['time'].max() - df['time'].min())
# Out:
# 2018-03-24 13:15:39
# 2015-12-10 14:39:21
# 834 days 22:36:18

# %%
df.count()
# Out:
# latitude        286832
# longitude       286832
# description     286832
# zip             286832
# type            286832
# time            286832
# town            286783
# address         286832
# if_emergency    286832
# dtype: int64

# %%
df.head()
# Out:
#     latitude  longitude                                        description  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 5  40.253473 -75.283245  CANNON AVE & W 9TH ST;  LANSDALE; Station 345;...
#
#        zip                     type                time               town  \
# 0  19525.0   EMS: BACK PAINS/INJURY 2015-12-10 17:10:52        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY 2015-12-10 17:29:21  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK 2015-12-10 14:39:21         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY 2015-12-10 16:47:36         NORRISTOWN
# 5  19446.0         EMS: HEAD INJURY 2015-12-10 15:39:04           LANSDALE
#
#                       address  if_emergency
# 0      REINDEER CT & DEAD END             1
# 1  BRIAR PATH & WHITEMARSH LN             1
# 2                    HAWS AVE             1
# 3          AIRY ST & SWEDE ST             1
# 5       CANNON AVE & W 9TH ST             1

# %% [markdown]
# ## 1. General Exploration (1/4)

# %% [markdown]
# ### 1.1. Ranking emergency categories by frequency

# %%
df2= df.groupby('type')

# %%
grouped = df.groupby('type').agg({'type':'count'}).sort_values('type')[::-1][:30]/len(df)*100
# Out:
# C:\Users\kdabhadk\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: 'type' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
#   """Entry point for launching an IPython kernel.

# %%
grouped
# Out:
#                                            type
# type
# Traffic: VEHICLE ACCIDENT -           22.573492
# Traffic: DISABLED VEHICLE -            6.560983
# Fire: FIRE ALARM                       6.059296
# EMS: RESPIRATORY EMERGENCY             5.467312
# EMS: FALL VICTIM                       5.401768
# EMS: CARDIAC EMERGENCY                 5.247322
# EMS: SUBJECT IN PAIN                   3.009427
# Traffic: ROAD OBSTRUCTION -            3.004546
# EMS: HEAD INJURY                       2.809659
# EMS: VEHICLE ACCIDENT                  2.799200
# EMS: SYNCOPAL EPISODE                  1.811165
# EMS: UNKNOWN MEDICAL EMERGENCY         1.782577
# EMS: GENERAL WEAKNESS                  1.750502
# EMS: SEIZURES                          1.743878
# EMS: ALTERED MENTAL STATUS             1.565725
# Fire: FIRE INVESTIGATION               1.526329
# EMS: ABDOMINAL PAINS                   1.516567
# EMS: MEDICAL ALERT ALARM               1.491465
# EMS: HEMORRHAGING                      1.350965
# EMS: UNCONSCIOUS SUBJECT               1.332487
# EMS: CVA/STROKE                        1.331790
# EMS: OVERDOSE                          1.310175
# EMS: NAUSEA/VOMITING                   1.259274
# Fire: VEHICLE ACCIDENT                 1.200006
# Fire: GAS-ODOR/LEAK                    1.072056
# Traffic: HAZARDOUS ROAD CONDITIONS -   1.044165
# EMS: DIABETIC EMERGENCY                0.913775
# EMS: DIZZINESS                         0.830800
# Fire: BUILDING FIRE                    0.802909
# EMS: BACK PAINS/INJURY                 0.798377

# %%
xi = grouped.values[:,0]
yi = grouped.index
plt.subplots(figsize=(20,15))
sns.barplot(x=xi,y=yi,color='r')


sns.set(style="whitegrid")
sns.set_color_codes("muted")
sns.set(font_scale=2)   
sns.despine(left=True, bottom=True)

sns.set(font_scale=2)
plt.xlim=(0,25)
plt.ylabel("Emergency")
plt.xlabel("Percentage of all 911 calls")
plt.title('30 most frequent reasons for 911 calls')
# Out:
# Text(0.5,1,'30 most frequent reasons for 911 calls')

# %%
## Categorizing data by emergency type
df_title_cat = pd.DataFrame(df.type.str.split(':',1).tolist(),columns = ['emergency_type','emergency_subtype'])
df_cat = df.copy()
del df_cat['type']
df_cat.insert(4,'emergency_type',df_title_cat['emergency_type'].values)
df_cat.insert(5,'emergency_subtype',df_title_cat['emergency_subtype'].values)

# %%
df_cat.head()
# Out:
#     latitude  longitude                                        description  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 5  40.253473 -75.283245  CANNON AVE & W 9TH ST;  LANSDALE; Station 345;...
#
#        zip emergency_type    emergency_subtype                time  \
# 0  19525.0            EMS    BACK PAINS/INJURY 2015-12-10 17:10:52
# 1  19446.0            EMS   DIABETIC EMERGENCY 2015-12-10 17:29:21
# 2  19401.0           Fire        GAS-ODOR/LEAK 2015-12-10 14:39:21
# 3  19401.0            EMS    CARDIAC EMERGENCY 2015-12-10 16:47:36
# 5  19446.0            EMS          HEAD INJURY 2015-12-10 15:39:04
#
#                 town                     address  if_emergency
# 0        NEW HANOVER      REINDEER CT & DEAD END             1
# 1  HATFIELD TOWNSHIP  BRIAR PATH & WHITEMARSH LN             1
# 2         NORRISTOWN                    HAWS AVE             1
# 3         NORRISTOWN          AIRY ST & SWEDE ST             1
# 5           LANSDALE       CANNON AVE & W 9TH ST             1

# %%
grouped_by_type = df_cat.groupby('emergency_type').agg(
    {'emergency_type':'count'}).sort_values('emergency_type')[::-1][:10]/len(df_cat)*100
# Out:
# C:\Users\kdabhadk\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: 'emergency_type' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version

# %%
grouped = grouped_by_type
yi = grouped.values[:,0]
xi = grouped.index
plt.subplots(figsize=(3,7))
sns.barplot(x=xi,y=yi,color='b')


sns.set(style="whitegrid")
sns.set_color_codes("muted")
sns.set(font_scale=2)   
sns.despine(left=True, bottom=True)

sns.set(font_scale=1)
plt.style.use('fivethirtyeight')
plt.xlim=(0,100)
plt.xlabel("")

plt.title('All 911 calls Grouped by Emergency Types')
# Out:
# Text(0.5,1,'All 911 calls Grouped by Emergency Types')

# %%
grouped_by_emstype = df_cat[df_cat['emergency_type']=='EMS'].groupby('emergency_subtype').agg({
    'emergency_type':'count'}).sort_values('emergency_type')[::-1][:10]/len(df_cat)*100

# %%
grouped = grouped_by_emstype
xi = grouped.values[:,0]/sum(grouped.values[:,0])*100
yi = grouped.index
plt.subplots(figsize=(20,7))
sns.barplot(x=xi,y=yi,color='r')


sns.set(style="whitegrid")
sns.set_color_codes("muted")
sns.set(font_scale=2)   
sns.despine(left=True, bottom=True)

sns.set(font_scale=1.5)
plt.xlim=(0,100)
plt.ylabel("")
plt.xlabel("Percentage of All EMS Calls")
plt.title('EMS Calls Grouped by Emergency Sub-type')
# Out:
# Text(0.5,1,'EMS Calls Grouped by Emergency Sub-type')

# %%
grouped_by_traffictype = df_cat[df_cat['emergency_type']=='Traffic'].groupby('emergency_subtype').agg({
    'emergency_type':'count'}).sort_values('emergency_type')[::-1][:10]/len(df_cat)*100

# %%
grouped = grouped_by_traffictype
xi = grouped.values[:,0]/sum(grouped.values[:,0])*100
yi = grouped.index
plt.subplots(figsize=(20,7))
sns.barplot(x=xi,y=yi,color='r')

sns.set(style="whitegrid")
sns.set_color_codes("muted")
sns.set(font_scale=2)   
sns.despine(left=True, bottom=True)

sns.set(font_scale=1.5)
plt.xlim=(0,100)
plt.ylabel("")
plt.xlabel("Percentage of All Traffic calls")
plt.title('Traffic Calls Grouped by Emergency Sub-type')
# Out:
# Text(0.5,1,'Traffic Calls Grouped by Emergency Sub-type')

# %%
grouped_by_firetype = df_cat[df_cat['emergency_type']=='Fire'].groupby('emergency_subtype').agg({
    'emergency_type':'count'}).sort_values('emergency_type')[::-1][:10]/len(df_cat)*100

# %%
grouped = grouped_by_firetype
xi = grouped.values[:,0]/sum(grouped.values[:,0])*100
yi = grouped.index
plt.subplots(figsize=(20,7))
sns.barplot(x=xi,y=yi,color='r')

sns.set(style="whitegrid")
sns.set_color_codes("muted")
sns.set(font_scale=2)   
sns.despine(left=True, bottom=True)

sns.set(font_scale=1.5)
plt.xlim=(0,100)
plt.ylabel("")
plt.xlabel("Percentage of All Fire calls")
plt.title('Fire Calls Grouped by Emergency Sub-type')
# Out:
# Text(0.5,1,'Fire Calls Grouped by Emergency Sub-type')

# %% [markdown]
# ## 2. Location-based Exploration

# %% [markdown]
# ### 2.1. Emergency categories by town

# %%
count_by_town = df_cat[df_cat['emergency_type'] == 'EMS'].groupby('town').agg({'town':'count'}).sort_values('town')[::-1][:20]
# Out:
# C:\Users\kdabhadk\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: 'town' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
#   """Entry point for launching an IPython kernel.

# %%
grouped = count_by_town
xi = grouped.values[:,0]/1000
yi = grouped.index
plt.subplots(figsize=(20,7))
sns.barplot(x=xi,y=yi,color='r')

sns.set(style="whitegrid")
sns.set_color_codes("muted")
sns.set(font_scale=2)   
sns.despine(left=True, bottom=True)

sns.set(font_scale=1.5)
plt.xlim=(0,100)
plt.ylabel("")
plt.xlabel("1000 Calls")
plt.title('EMS Calls Grouped by Town')
# Out:
# Text(0.5,1,'EMS Calls Grouped by Town')

# %%
count_by_zip = df_cat[df_cat['emergency_type'] == 'EMS'].groupby('zip').agg({'zip':'count'}).sort_values('zip')[::-1].iloc[:20]
count_by_zip.columns = ['count']
# Out:
# C:\Users\kdabhadk\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: 'zip' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
#   """Entry point for launching an IPython kernel.

# %%
grouped = count_by_zip
yi = count_by_zip['count']
xi = count_by_zip.index
plt.subplots(figsize=(20,7))
sns.barplot(x=xi,y=yi,color='r')

sns.set(style="whitegrid")
sns.set_color_codes("muted")
sns.set(font_scale=2)   
sns.despine(left=True, bottom=True)

sns.set(font_scale=1.5)
plt.xlim=(0,100)
plt.ylabel("1000 Calls")
plt.title('EMS Calls Grouped by zip')
# Out:
# Text(0.5,1,'EMS Calls Grouped by zip')

# %%
count_by_zip = df_cat.groupby('zip').agg({'zip':'count'}).sort_values('zip')[::-1]
count_by_zip['cumsum_percent'] = count_by_zip.cumsum()/len(df)*100
count_by_zip.columns = ['count','cumsum_percent']
# Out:
# C:\Users\kdabhadk\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: 'zip' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
#   """Entry point for launching an IPython kernel.

# %%
count_by_zip[count_by_zip['cumsum_percent']<81].count()/len(count_by_zip)
# 80% of all EMS calls originated only from about 25% of zip codes
# 99% of all EMS calls originated only from about 45% of zip codes
# Out:
# count             0.2
# cumsum_percent    0.2
# dtype: float64

# %%
plt.plot(range(len(count_by_zip)),count_by_zip['cumsum_percent'])
plt.xlabel('Number of Zip Codes')
plt.ylabel('Percent of all EMS Calls')
plt.axhline(y = 80,xmin = 0,xmax =0.22,color = 'r')
plt.axvline(x = 26,ymax = 0.75,color='r')

plt.show()

# %%
print (str(len(df_cat['zip'].unique()))+' unique zip codes.')
print (str(len(df_cat['town'].unique()))+ ' unique towns.')
# Out:
# 135 unique zip codes.
# 69 unique towns.

# %% [markdown]
# ## Plot all calls on map

# %% [markdown]
# <img src ="calls_by_zip.png">

# %% [markdown]
# ## Plot EMS calls on map

# %%
only_EMS_view = df_cat[df_cat['emergency_type']=='EMS']

# %%
only_EMS_view.to_csv('segregated_data.csv')

# %%
only_EMS_view
# Out:
#          latitude  longitude  \
# 0       40.297876 -75.581294
# 1       40.258061 -75.264680
# 3       40.116153 -75.343513
# 5       40.253473 -75.283245
# 6       40.182111 -75.127795
# 7       40.217286 -75.405182
# 8       40.289027 -75.399590
# 16      40.243258 -75.286552
# 17      40.312181 -75.574260
# 18      40.114239 -75.338508
# 25      40.133037 -75.408463
# 26      40.155283 -75.264230
# 31      40.300736 -75.331973
# 32      40.129398 -75.332213
# 40      40.122780 -75.267241
# 44      40.224923 -75.528045
# 51      40.320966 -75.611349
# 55      40.133037 -75.408463
# 56      40.089973 -75.141085
# 57      40.247002 -75.652597
# 61      40.117345 -75.211173
# 62      40.267925 -75.314382
# 63      40.245673 -75.279667
# 64      40.119946 -75.338321
# 65      40.105308 -75.341987
# 66      40.289027 -75.399590
# 67      40.245731 -75.341687
# 68      40.133037 -75.408463
# 69      40.154659 -75.221544
# 71      39.986770 -75.275433
# ...           ...        ...
# 326348  40.037753 -75.317595
# 326349  40.005547 -75.236700
# 326350  40.137991 -75.120308
# 326351  40.011767 -75.294673
# 326353  39.996720 -75.237830
# 326354  40.117382 -75.342850
# 326357  40.225099 -75.207651
# 326358  40.376450 -75.481847
# 326359  40.100748 -75.215108
# 326362  40.170972 -75.021235
# 326363  40.391060 -75.499938
# 326364  40.110599 -75.110360
# 326365  40.118065 -75.307101
# 326366  40.002482 -75.271529
# 326367  40.253000 -75.291244
# 326368  40.244066 -75.614662
# 326369  40.311629 -75.331096
# 326373  40.189065 -75.177156
# 326378  40.169082 -75.469631
# 326379  40.280731 -75.642440
# 326381  40.106839 -75.123804
# 326383  40.133037 -75.408463
# 326385  40.271939 -75.463517
# 326387  40.151467 -75.117697
# 326388  40.078920 -75.359199
# 326391  40.099162 -75.149660
# 326396  40.251370 -75.465710
# 326397  40.337793 -75.548971
# 326402  40.051051 -75.113190
# 326412  40.089604 -75.148337
#
#                                               description      zip  \
# 0       REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1       BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 3       AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 5       CANNON AVE & W 9TH ST;  LANSDALE; Station 345;...  19446.0
# 6       LAUREL AVE & OAKDALE AVE;  HORSHAM; Station 35...  19044.0
# 7       COLLEGEVILLE RD & LYWISKI RD;  SKIPPACK; Stati...  19426.0
# 8       MAIN ST & OLD SUMNEYTOWN PIKE;  LOWER SALFORD;...  19438.0
# 16      SUSQUEHANNA AVE & W MAIN ST;  LANSDALE; Statio...  19446.0
# 17      CHARLOTTE ST & MILES RD;  NEW HANOVER; Station...  19525.0
# 18      PENN ST & ARCH ST;  NORRISTOWN; Station 308A; ...  19401.0
# 25      SHANNONDELL DR & SHANNONDELL BLVD;  LOWER PROV...  19403.0
# 26      PENLLYN BLUE BELL PIKE & VILLAGE CIR;  WHITPAI...  19422.0
# 31      CORNWALL TER & LIONS GATE CIR;  FRANCONIA; Sta...  18964.0
# 32      PINE ST & W ROBERTS ST;  NORRISTOWN; Station 3...  19401.0
# 326067  EAST NORRITON  DEKALB PIKE & W GERMANTOWN PIKE             1
# 326106     NORRISTOWN         BUTTONWOOD ST & W OAK ST             1
# 326131     NORRISTOWN     JOHNSON HWY & NORTH HILLS DR             1
# 326135  EAST NORRITON        DEKALB PIKE & COLONIAL DR             1
# 326139  EAST NORRITON              CAROL LN & ROBIN LN             1
# 326150     NORRISTOWN           LINCOLN AVE & SWEDE ST             1
# 326183     NORRISTOWN            FREEDLEY ST & PINE ST             1
# 326189     NORRISTOWN           PINE ST & W ROBERTS ST             1
# 326192     NORRISTOWN            FREEDLEY ST & PINE ST             1
# 326195     NORRISTOWN           MARSHALL ST & ASTOR ST             1
# 326198     NORRISTOWN             BASIN ST & GRADY ALY             1
# 326219     NORRISTOWN     ROBERTS ST & GLENN VALLEY DR             1
# 326243     NORRISTOWN                  W WASHINGTON ST             1
# 326306     NORRISTOWN               MAIN ST & CHAIN ST             1
# 326312     NORRISTOWN            DEKALB ST & E MAIN ST             1
# 326316     NORRISTOWN                GARY LN & HIGH ST             1
# 326347     NORRISTOWN            WALNUT ST & E MAIN ST             1
# 326354     NORRISTOWN           MARSHALL ST & SWEDE ST             1
#
# [22136 rows x 10 columns]

# %%
us_pop = pd.read_csv('us-population-by-zip-code/population_by_zip_2010.csv')

# %%
us_pop.head()
# Out:
#    population  minimum_age  maximum_age  gender  zipcode          geo_id
# 0          50         30.0         34.0  female    61747  8600000US61747
# 1           5         85.0          NaN    male    64120  8600000US64120
# 2        1389         30.0         34.0    male    95117  8600000US95117
# 3         231         60.0         61.0  female    74074  8600000US74074
# 4          56          0.0          4.0  female    58042  8600000US58042

# %%
us_pop_by_zip = us_pop[us_pop['zipcode'].isin(df_cat['zip'].unique())].groupby('zipcode').agg({'population':'sum'})

# %%
result = pd.concat([us_pop_by_zip, count_by_zip], axis=1, sort=False)

# %%
result.dropna(inplace=True)

# %%
result.sort_values('population').corr()
# As seen, population and EMS calls are very poorly correlated
# Out:
#                 population     count  cumsum_percent
# population        1.000000  0.249869       -0.229612
# count             0.249869  1.000000       -0.977542
# cumsum_percent   -0.229612 -0.977542        1.000000

# %% [markdown]
# ## 3. Analyze EMS Calls according to time

# %%
sns.distplot(df_cat[df_cat['emergency_type'] == 'EMS']['time'].dt.hour,bins=24)
plt.ylabel('Inverse of calls per hour')
plt.show()

# %%
sns.distplot(df_cat[df_cat['emergency_type'] == 'EMS']['time'].dt.hour[df_cat['time'].dt.month==6],bins=24,label='June')
sns.distplot(df_cat[df_cat['emergency_type'] == 'EMS']['time'].dt.hour[df_cat['time'].dt.month==12],bins=24,label='December')
plt.ylabel('Inverse of calls per hour')
plt.legend()
plt.show()

# %%
sns.distplot(df_cat[df_cat['emergency_subtype'] == ' RESPIRATORY EMERGENCY']['time'].dt.hour[df_cat['time'].dt.month==6],bins=24,label='June')
sns.distplot(df_cat[df_cat['emergency_subtype'] == ' RESPIRATORY EMERGENCY']['time'].dt.hour[df_cat['time'].dt.month==12],bins=24,label='December')
plt.ylabel('Inverse of calls per hour')
plt.legend()
plt.show()
